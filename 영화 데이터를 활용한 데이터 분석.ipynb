# %% [markdown]
# # 영화 관객 수 데이터를 활용한 데이터 분석

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import lightgbm as lgb

# %%
train = pd.read_csv('movies_train.csv')    # 모델을 학습할 때 사용
test = pd.read_csv('movies_test.csv')    # 모델을 평가할 때 사용
submission = pd.read_csv('submission.csv')    # 답안지

# %% [markdown]
# train data는 쉽게 말해 내가 가지고 있는 정보이다. 가지고 있는 정보를 가지고 unseen data를 예측 혹은 분류하는 것이 최종 목적이다.

# %%
# 데이터셋의 형태를 확인
train.head()
# Out:
#        title   distributor genre release_time  time screening_rat director  \
# 0     개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1       내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2  은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3   나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4       불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# 0             NaN             0         91          2        23398
# 1      1161602.50             2        387          3      7072501
# 2       220775.25             4        343          4      6959083
# 3        23894.00             2         20          6       217866
# 4            1.00             1        251          2       483387

# %% [markdown]
# - title : 영화의 제목
# - distributor : 배급사
# - genre : 장르
# - release_time : 개봉일
# - time : 상영시간(분)
# - screening_rat : 상영등급
# - director : 감독이름
# - dir_prev_bfnum : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
# - dir_prev_num : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)
# - num_staff : 스텝수
# - num_actor : 주연배우수
# - box_off_num : 관객수

# %% [markdown]
# unseen data는 말 그대로 아직 일어나지 않은 일의 데이터이다.(존재하지 않는 데이터)
# 그래서 현재 가진 데이터를 train과 test로 나눠서 train으로만 학습하면서 최적의 매개변수를 찾고, test를 사용하여 모델의 실력을 평가할 수 있다.
# test data는 unseen data의 역할을 하게되는 것이다.

# %%
# 테스팅
test.head()
# Out:
#          title distributor   genre release_time  time screening_rat director  \
# 0       용서는 없다      시네마서비스     느와르   2010-01-07   125      청소년 관람불가      김형준
# 1  아빠가 여자를 좋아해      (주)쇼박스  멜로/로맨스   2010-01-14   113       12세 관람가      이광재
# 2          하모니   CJ 엔터테인먼트     드라마   2010-01-28   115       12세 관람가      강대규
# 3          의형제      (주)쇼박스      액션   2010-02-04   116       15세 관람가       장훈
# 4        평행 이론   CJ 엔터테인먼트      공포   2010-02-18   110       15세 관람가      권호영
#
#    dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# 0    3.005290e+05             2        304          3
# 1    3.427002e+05             4        275          3
# 2    4.206611e+06             3        419          7
# 3    6.913420e+05             2        408          2
# 4    3.173800e+04             1        380          1

# %%
# 결과를 내야하는 데이터셋
submission.head()
# Out:
#          title  box_off_num
# 0       용서는 없다            0
# 1  아빠가 여자를 좋아해            0
# 2          하모니            0
# 3          의형제            0
# 4        평행 이론            0

# %%
# 세개의 데이터 셋의 행과 열의 수 확인
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (600, 12)
# (243, 11)
# (243, 2)

# %% [markdown]
# test data는 모델이 예측해서 결과를 내야하는 box_off_num 컬럼을 가지지 않는다.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           600 non-null    object
#  1   distributor     600 non-null    object
#  2   genre           600 non-null    object
#  3   release_time    600 non-null    object
#  4   time            600 non-null    int64
#  5   screening_rat   600 non-null    object
#  6   director        600 non-null    object
#  7   dir_prev_bfnum  270 non-null    float64
#  8   dir_prev_num    600 non-null    int64
#  9   num_staff       600 non-null    int64
#  10  num_actor       600 non-null    int64
#  11  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 56.4+ KB

# %% [markdown]
# info 함수는 데이터셋의 컬럼별 정보를 알려준다.

# %% [markdown]
# ## 전처리

# %% [markdown]
# - 결측치 여부를 확인해준다.
# - isna를 통해 결측치 확인할 수 있다.

# %%
train.isna()
# Out:
#      title  distributor  genre  release_time   time  screening_rat  director  \
# 0    False        False  False         False  False          False     False
# 1    False        False  False         False  False          False     False
# 2    False        False  False         False  False          False     False
# 3    False        False  False         False  False          False     False
# 4    False        False  False         False  False          False     False
# ..     ...          ...    ...           ...    ...            ...       ...
# 595  False        False  False         False  False          False     False
# 596  False        False  False         False  False          False     False
# 597  False        False  False         False  False          False     False
# 598  False        False  False         False  False          False     False
# 599  False        False  False         False  False          False     False
#
# ...

# %%
# dir_prev_bfnum 컬럼에 결측값이 330개 있는 것을 확인
train.isna().sum()
# Out:
# title               0
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    330
# dir_prev_num        0
# num_staff           0
# num_actor           0
# box_off_num         0
# dtype: int64

# %%
# 결측값이 있는 행들만 출력
train[train["dir_prev_bfnum"].isna()]
# Out:
#                title      distributor   genre release_time  time  \
# 0             개들의 전쟁         롯데엔터테인먼트      액션   2012-11-22    96
# 6               길위에서             백두대간   다큐멘터리   2013-05-23   104
# 8    1789, 바스티유의 연인들  유니버설픽쳐스인터내셔널코리아     뮤지컬   2014-09-18   129
# 9              청춘그루브           (주)두타연     드라마   2012-03-15    94
# 10            AV 아이돌        (주) 케이알씨지  멜로/로맨스   2015-07-27    89
# ..               ...              ...     ...          ...   ...
# 593       낭만파 남편의 편지             퍼스트런    미스터리   2013-09-12    97
# 594         오빠가 돌아왔다        (주)마운틴픽쳐스     코미디   2014-03-20    94
# 597            살인의 강        (주)마운틴픽쳐스      공포   2010-09-30    99
# 598           악의 연대기        CJ 엔터테인먼트     느와르   2015-05-14   102
# 599              베를린        CJ 엔터테인먼트      액션   2013-01-30   120
#
#     screening_rat director  dir_prev_bfnum  dir_prev_num  num_staff  \
# 0        청소년 관람불가      조병옥             NaN             0         91
# ...

# %% [markdown]
# 관객수가 알려지지 않았기 때문에 영화가 제외되었음을 추측하고
# fillna() 함수로 결측치를 0으로 채워줄 수 있다.

# %%
train["dir_prev_bfnum"].fillna(0, inplace=True)
train
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
test.isna().sum()
# Out:
# title               0
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    136
# dir_prev_num        0
# num_staff           0
# num_actor           0
# dtype: int64

# %% [markdown]
# test 데이터 셋의 결측값도 확인

# %%
test[test["dir_prev_bfnum"].isna()]
# Out:
#                title      distributor   genre release_time  time  \
# 5             회오리 바람             모쿠슈라     드라마   2010-02-25    95
# 6             경계도시 2            시네마 달   다큐멘터리   2010-03-18   104
# 7             이웃집 남자        (주)루믹스미디어     드라마   2010-03-18   100
# 8        아마존의 눈물 극장판           마운틴픽쳐스   다큐멘터리   2010-03-25    88
# 9            반가운 살인자  롯데쇼핑(주)롯데엔터테인먼트     코미디   2010-04-08   107
# ..               ...              ...     ...          ...   ...
# 235              타이밍      (주)스톰픽쳐스코리아   애니메이션   2015-12-10   100
# 237           어떤이의 꿈              하준사     드라마   2015-11-26    72
# 239           울보 권투부            인디스토리   다큐멘터리   2015-10-29    86
# 240             어떤살인       (주)컨텐츠온미디어     느와르   2015-10-28   107
# 242  조선안방 스캔들-칠거지악 2        (주) 케이알씨지  멜로/로맨스   2015-10-22    76
#
#     screening_rat director  dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# 5         15세 관람가      장건재             NaN             0        156          2
# ...

# %%
test["dir_prev_bfnum"].fillna(0, inplace=True)
test
# Out:
#                title  distributor   genre release_time  time screening_rat  \
# 0             용서는 없다       시네마서비스     느와르   2010-01-07   125      청소년 관람불가
# 1        아빠가 여자를 좋아해       (주)쇼박스  멜로/로맨스   2010-01-14   113       12세 관람가
# 2                하모니    CJ 엔터테인먼트     드라마   2010-01-28   115       12세 관람가
# 3                의형제       (주)쇼박스      액션   2010-02-04   116       15세 관람가
# 4              평행 이론    CJ 엔터테인먼트      공포   2010-02-18   110       15세 관람가
# ..               ...          ...     ...          ...   ...           ...
# 238        해에게서 소년에게          디씨드     드라마   2015-11-19    78       15세 관람가
# 239           울보 권투부        인디스토리   다큐멘터리   2015-10-29    86       12세 관람가
# 240             어떤살인   (주)컨텐츠온미디어     느와르   2015-10-28   107      청소년 관람불가
# 241        말하지 못한 비밀  (주)씨타마운틴픽쳐스     드라마   2015-10-22   102      청소년 관람불가
# 242  조선안방 스캔들-칠거지악 2    (주) 케이알씨지  멜로/로맨스   2015-10-22    76      청소년 관람불가
#
#     director  dir_prev_bfnum  dir_prev_num  num_staff  num_actor
# ...

# %% [markdown]
# ## 모델링

# %% [markdown]
# - 최종적으로 영화 관객 수를 예측하는 모델을 만든다.
# - X(상영 시간, 영화 제작에 참여한 스태프 수, 배우 수 등..) -> MODEL -> Y(영화 관객 수)

# %%
# lightgbm 모델을 사용
model = lgb.LGBMRegressor(random_state=777, n_estimators=1000)

# %% [markdown]
# - LightGBM 모델
#     - 부스팅 모델
#     - 기존 모델이 못 맞춘 문제에 가중치를 두어 지속적으로 학습을 이어나감
#     - 타 부스팅 모델에 비해 속도가 빠름

# %% [markdown]
# ### Feature Engineering & Initial Modeling

# %%
features = ["time", "dir_prev_num", "num_staff", "num_actor"]
target = ["box_off_num"]

# %%
X_train, X_test, y_train = train[features], test[features], train[target]

# %% [markdown]
# ### lightGBM (base model) 사용

# %%
# 모델 학습
model.fit(X_train, y_train)
# Out:
# LGBMRegressor(n_estimators=1000, random_state=777)

# %%
# 답안지
singleLGBM = submission.copy()

# %%
singleLGBM.head()
# Out:
#          title   box_off_num
# 0       용서는 없다  2.817995e+06
# 1  아빠가 여자를 좋아해  3.753772e+05
# 2          하모니 -5.693243e+05
# 3          의형제  1.581189e+06
# 4        평행 이론 -5.277806e+05

# %%
# 예측값 산출해서 답안지에 입력
singleLGBM["box_off_num"] = model.predict(X_test)

# %%
# 관객 수에 음수가 나타남.
# 성능이 좋지 못함을 알 수 있다.
singleLGBM.to_csv
# Out:
# <bound method NDFrame.to_csv of                title   box_off_num
# 0             용서는 없다  2.817995e+06
# 1        아빠가 여자를 좋아해  3.753772e+05
# 2                하모니 -5.693243e+05
# 3                의형제  1.581189e+06
# 4              평행 이론 -5.277806e+05
# ..               ...           ...
# 238        해에게서 소년에게  5.007844e+05
# 239           울보 권투부  1.013858e+06
# 240             어떤살인  1.682068e+06
# 241        말하지 못한 비밀  3.002163e+05
# 242  조선안방 스캔들-칠거지악 2  1.139003e+04
#
# [243 rows x 2 columns]>

# %% [markdown]
# ### k-fold 교차검증
# - 과대적합 방지
# - 모델 간 일반적인 성능 비교
# - validation set, development set

# %%
from sklearn.model_selection import KFold

# %%
k_fold = KFold(n_splits=5, shuffle=True, random_state=777)

# %% [markdown]
# 5등분하여 split

# %%
for train_idx, val_idx in k_fold.split(X_train):
    print(len(train_idx), len(val_idx))
    break
# Out:
# 480 120

# %%
model = lgb.LGBMRegressor(random_state=777, n_estimators=1000)

models = []

for train_idx, val_idx in k_fold.split(X_train):
    x_t = X_train.iloc[train_idx]
    y_t = y_train.iloc[train_idx]
    x_val = X_train.iloc[val_idx]
    y_val = y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set=(x_val, y_val), early_stopping_rounds=100, verbose = 100))
# Out:
# [100]	valid_0's l2: 2.70572e+12
# [100]	valid_0's l2: 3.90847e+12
# [100]	valid_0's l2: 3.50344e+12
# [100]	valid_0's l2: 1.45977e+12
# [100]	valid_0's l2: 1.77214e+12

# %%
models
# Out:
# [LGBMRegressor(n_estimators=1000, random_state=777),
#  LGBMRegressor(n_estimators=1000, random_state=777),
#  LGBMRegressor(n_estimators=1000, random_state=777),
#  LGBMRegressor(n_estimators=1000, random_state=777),
#  LGBMRegressor(n_estimators=1000, random_state=777)]

# %% [markdown]
# 모델링 결과 preds에 저장

# %%
preds = []
for model in models:
    preds.append(model.predict(X_test))
len(preds)
# Out:
# 5

# %%
kfoldLightGBM = submission.copy()

# %%
import numpy as np

# %%
kfoldLightGBM["box_off_num"] = np.mean(preds, axis = 0)

# %%
kfoldLightGBM.head()
# Out:
#          title   box_off_num
# 0       용서는 없다  3.367422e+06
# 1  아빠가 여자를 좋아해  9.611389e+05
# 2          하모니  1.097930e+06
# 3          의형제  2.097271e+06
# 4        평행 이론  7.814763e+05

# %%
kfoldLightGBM.to_csv('kfoldLightGBM.csv', index = False)
